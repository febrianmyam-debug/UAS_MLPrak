# %%
import os
import sys

# Pindah satu folder ke atas (root project)
PROJECT_ROOT = os.path.abspath("..")

if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.21.0

# %%
from src.data_loader import *

from src.visualization import *

from src.utils import *

# %%
set_seed()

# %%
df = load_dataset()
# Out:
# [2026-07-01 15:53:16] Loading dataset : C:\Users\LENOVO\Documents\kuliah\smt 4\mlp\UAS\dataset\heartv1.csv
# [2026-07-01 15:53:16] Dataset loaded successfully.

# %%
head(df)
# Out:
# ============================================================
# FIRST ROW
# ============================================================
#       sex  age  cp  resting_BP  chol  fbs  restecg  thalach   exang  oldpeak  \
# 0    male   65   0         130   254    0        0       147      0      1.4
# 1    male   53   0         140   261    0        0       186      1      0.0
# 2    male   50   0         122   222    0        0       186      0      0.0
# 3  female   47   1         112   160    0        1       138      0      0.0
# 4    male   47   0         142   309    0        0       147      1      0.0
#
#    slope  ca  thal  Max Heart Rate Reserve  Heart Disease Risk Score  target
# 0      1   1     3                      10                     11.44       0
# 1      2   0     2                     -17                     13.51       1
# 2      2   0     2                     -14                      9.46       1
# 3      1   0     2                      37                      8.34       1
# 4      1   3     3                      28                     13.43       0

# %%
tail(df)
# Out:
# ============================================================
# LAST ROW
# ============================================================
#          sex  age  cp  resting_BP  chol  fbs  restecg  thalach   exang  \
# 1030  female   45   2         145   195    0        1       180      1
# 1031    male   53   0         125   210    0        1       165      0
# 1032  female   60   1         130   240    1        0       150      1
# 1033    male   67   2         155   205    0        1       140      0
# 1034  female   59   0         110   175    0        1       172      1
#
#       oldpeak  slope  ca  thal  Max Heart Rate Reserve  \
# 1030      3.0      1   0     2                      -5
# 1031      0.8      1   1     3                       2
# 1032      2.2      2   2     1                      10
# 1033      1.1      0   0     2                      13
# 1034      2.5      1   3     2                     -11
#
#       Heart Disease Risk Score  target
# 1030                      15.9       1
# 1031                      13.2       0
# 1032                      18.8       1
# 1033                      16.1       0
# 1034                      12.9       1

# %%
dataset_summary(df)
# Out:
# ============================================================
# DATASET SHAPE
# ============================================================
# Rows    : 1035
# Columns : 16
# ============================================================
# DATASET INFO
# ============================================================
# <class 'pandas.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   sex                       1035 non-null   str
#  1   age                       1035 non-null   int64
#  2   cp                        1035 non-null   int64
#  3   resting_BP                1035 non-null   int64
#  4   chol                      1035 non-null   int64
#  5   fbs                       1035 non-null   int64
#  6   restecg                   1035 non-null   int64
#  7   thalach                   1035 non-null   int64
#  8   exang                     1035 non-null   int64
#  9   oldpeak                   1035 non-null   float64
#  10  slope                     1035 non-null   int64
#  11  ca                        1035 non-null   int64
#  12  thal                      1035 non-null   int64
#  13  Max Heart Rate Reserve    1035 non-null   int64
#  14  Heart Disease Risk Score  1035 non-null   float64
#  15  target                    1035 non-null   int64
# dtypes: float64(2), int64(13), str(1)
# memory usage: 134.2 KB
# ============================================================
# COLUMN LIST
# ============================================================
# 1. sex
# 2. age
# 3. cp
# 4. resting_BP
# 5. chol
# 6. fbs
# 7. restecg
# 8. thalach
# 9. exang
# 10. oldpeak
# 11. slope
# 12. ca
# 13. thal
# 14. Max Heart Rate Reserve
# 15. Heart Disease Risk Score
# 16. target
# ============================================================
# DATA TYPES
# ============================================================
# sex                             str
# age                           int64
# cp                            int64
# resting_BP                    int64
# chol                          int64
# fbs                           int64
# restecg                       int64
# thalach                       int64
# exang                         int64
# oldpeak                     float64
# slope                         int64
# ca                            int64
# thal                          int64
# Max Heart Rate Reserve        int64
# Heart Disease Risk Score    float64
# target                        int64
# dtype: object
# ============================================================
# DUPLICATE
# ============================================================
# Duplicate Data : 723
# ============================================================
# MISSING VALUE
# ============================================================
# ============================================================
# DESCRIPTIVE STATISTICS
# ============================================================
#                            count        mean        std     min     25%  \
# age                       1035.0   56.447343   9.098955   28.00   50.00
# cp                        1035.0    0.944928   1.029479    0.00    0.00
# resting_BP                1035.0  131.663768  17.503716   94.00  120.00
# chol                      1035.0  245.608696  51.532478  126.00  210.50
# fbs                       1035.0    0.150725   0.357953    0.00    0.00
# restecg                   1035.0    0.531401   0.527511    0.00    0.00
# thalach                   1035.0  149.182609  22.952151   71.00  132.00
# exang                     1035.0    0.338164   0.473313    0.00    0.00
# oldpeak                   1035.0    1.078937   1.174529    0.00    0.00
# slope                     1035.0    1.381643   0.620609    0.00    1.00
# ca                        1035.0    0.760386   1.033564    0.00    0.00
# thal                      1035.0    2.321739   0.621862    0.00    2.00
# Max Heart Rate Reserve    1035.0   16.339130  21.140178  -29.00    0.00
# Heart Disease Risk Score  1035.0   11.873952   2.235081    7.54   10.16
# target                    1035.0    0.513043   0.500071    0.00    0.00
#
#                              50%     75%    max
# age                        58.00   63.00   79.0
# cp                          1.00    2.00    3.0
# resting_BP                130.00  140.00  200.0
# chol                      240.00  275.00  564.0
# fbs                         0.00    0.00    1.0
# restecg                     1.00    1.00    2.0
# thalach                   152.00  166.00  202.0
# exang                       0.00    1.00    1.0
# oldpeak                     0.80    1.80    6.2
# slope                       1.00    2.00    2.0
# ca                          0.00    1.00    4.0
# thal                        2.00    3.00    3.0
# Max Heart Rate Reserve     12.00   28.00   82.0
# Heart Disease Risk Score   11.69   13.56   18.8
# target                      1.00    1.00    1.0

# %%
missing_value(df)
# Out:
# ============================================================
# MISSING VALUE
# ============================================================
#                           Missing  Percentage (%)
# sex                             0             0.0
# age                             0             0.0
# cp                              0             0.0
# resting_BP                      0             0.0
# chol                            0             0.0
# fbs                             0             0.0
# restecg                         0             0.0
# thalach                         0             0.0
# exang                           0             0.0
# oldpeak                         0             0.0
# slope                           0             0.0
# ca                              0             0.0
# thal                            0             0.0
# Max Heart Rate Reserve          0             0.0
# Heart Disease Risk Score        0             0.0
# target                          0             0.0

# %%
plot_distribution(df)

# %%
plot_boxplot(df)

# %%
plot_correlation(df)
